# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2

results = np.load('MSRVTT_sa_ft_models5/loss-1000.npy')

plt.plot(results) 

plt.ylabel("Loss") 
plt.xlabel("Number of Epoch")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2

results = np.load('MSRVTT_ft_models1/loss-700.npy')

plt.plot(results) 

plt.ylabel("Loss") 
plt.xlabel("Number of Epoch")
